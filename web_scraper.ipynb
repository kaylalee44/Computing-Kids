# %% [markdown]
# # Import and initialize packages and variables

# %%
# !pip install -q demjson
# Out:
#      |████████████████████████████████| 133kB 2.8MB/s
#   Building wheel for demjson (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
import sys
sys.path.append('/content/gdrive/My Drive/dsci')
import data_helpers
# import LabelSimplifier
import numpy
numpy.set_printoptions(threshold=sys.maxsize)
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)

import nltk
from nltk.tokenize import word_tokenize 
import shutil
import tensorflow as tf
import pickle
import keras
import numpy as np
import gensim
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import pandas as pd
import requests
import urllib3
from urllib.request import urlopen
import matplotlib.pyplot as plt
import re
import time
import demjson
from datetime import datetime, timedelta
import urllib
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

stateAbbrev_USA = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE",
                   "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS",
                   "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS",
                   "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY",
                   "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
                   "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV",
                   "WI", "WY"]

gen_headers = ['qualifications', 'qualified', 'skills', 'responsibilities', 'duties', 'abilities', 'experience']
required_headers = ['required', "must have", "essential", "needed", "minimum", "require", "basic", "at least"]
good_to_have_headers = ['preferred', "good to have", "nice to have"]
skills_labels = [".Htaccess", ".Net", ".Net-Core", "Abstraction", "Accounting", "Actionscript-3", "Activerecord",
                 "Administration", "Adobe", "Agile", "Ajax", "Algorithm", "Algorithms", "Amazon", "Amazon-Ec2",
                 "Amazon-S3", "Amazon-Web-Services", "Analysis", "Analytics", "Android", "Android-Activity",
                 "Android-Asynctask", "Android-Fragments", "Android-Intent", "Android-Layout", "Android-Listview",
                 "Android-Recyclerview", "Android-Studio", "Angular", "Angularjs", "Angularjs-Directive", "Animation",
                 "Ant", "Apache", "Apache-Flex", "Apache-Kafka", "Apache-Spark", "Api", "Api", "Apl", "App",
                 "Application", "Applications", "Architecture", "Architecture", "Arduino", "Arraylist", "Arrays",
                 "Artificial", "Asp.Net", "Asp.Net-Core", "Asp.Net-Mvc", "Asp.Net-Mvc-3", "Asp.Net-Mvc-4",
                 "Asp.Net-Mvc-5", "Asp.Net-Web-Api", "Assembly", "Assessment", "Asynchronous", "Audio",
                 "Authentication", "Autocomplete", "Automation", "Awk", "Aws", "Azure", "Backbone.Js", "Backend",
                 "Bash", "Basic", "Batch-File", "Beautifulsoup", "Big", "Binding", "Bitmap", "Blender", "Blueprint",
                 "Bluetooth", "Boost", "Bootstrap-4", "Browser", "Build", "Button", "C", "C#", "C#-4.0", "C#/.Net",
                 "C++", "C++11", "Caching", "Caffe", "Cakephp", "Callback", "Caml", "Canvas", "Cassandra", "Casting",
                 "Certifications", "Charts", "Checkbox", "Chemistry", "Clang", "Class", "Clojure", "Cloud",
                 "Cloud/Saas", "Cloudkit", "Cmake", "Cmd", "Cms", "Cocoa", "Cocoa-Touch", "Code", "Codeigniter",
                 "Coding", "Collections", "Colors", "Combobox", "Command-Line", "Communication", "Communications",
                 "Compiler-Errors", "Compiling", "Complex", "Computer", "Computing", "Concurrency", "Configuration",
                 "Constructor", "Control", "Cookies", "Cordova", "Core-Data", "Count", "Creative", "Crm",
                 "Cryptography", "Css", "Css3", "Csv", "Cuda", "Curl", "Customer", "Cyber", "D3.Js", "Dart", "Data",
                 "Data-Binding", "Data-Structures", "Database", "Database-Design", "Dataframe", "Datagrid",
                 "Datagridview", "Datatable", "Datatables", "Date", "Datepicker", "Datetime", "Debugging", "Deep",
                 "Delivery", "Delphi", "Dependency-Injection", "Deployment", "Description", "Design", "Design-Patterns",
                 "Development", "Devise", "Dictionary", "Digital", "Directory", "Django", "Django-Models",
                 "Django-Rest-Framework", "Dll", "Docker", "Doctrine-Orm", "Documentation", "Dom", "Download", "Dplyr",
                 "Drop-Down-Menu", "Drupal", "Dynamic", "Eclipse", "Ecmascript-6", "Elasticsearch", "Electrical",
                 "Elixir", "Eloquent", "Emacs", "Email", "Ember.Js", "Encapsulation", "Encoding", "Encryption",
                 "Engineer", "Engineering", "Engineering", "Enterprise", "Entity-Framework", "Enums", "Enzyme", "Erp",
                 "Error-Handling", "Evaluation", "Events", "Excel", "Excel-Formula", "Excel-Vba", "Exception",
                 "Exception-Handling", "Experience", "Express", "Extjs", "Facebook", "Facebook-Graph-Api", "Ffmpeg",
                 "File", "File-Io", "File-Upload", "Filter", "Firebase", "Firebase-Realtime-Database", "Firefox",
                 "Firewalls", "Flash", "Flask", "Flow", "Flutter", "Fonts", "For-Loop", "Foreach", "Forms", "Fortran",
                 "Framework", "Frameworks", "Frontend", "Full", "Function", "Functional-Programming", "Functionality",
                 "Gcc", "Generics", "Ggplot2", "Git", "Github", "Go", "Golang", "Google-Analytics", "Google-Api",
                 "Google-App-Engine", "Google-Apps-Script", "Google-Chrome", "Google-Chrome-Extension",
                 "Google-Cloud-Platform", "Google-Maps", "Google-Maps-Api-3", "Google-Sheets", "Gradle", "Grails",
                 "Graph", "Graphics", "Gridview", "Groovy", "Group-By", "Gwt", "Hadoop", "Hardware", "Hash", "Haskell",
                 "Hdl", "Heroku", "Hibernate", "Highcharts", "Hive", "Hml", "Host-Based", "Html", "Html5", "Html-Table",
                 "Http", "Https", "Human", "Hyperlink", "Ict", "If-Statement", "Iframe", "Iis", "Image",
                 "Image-Processing", "Immutable.Js", "Implementation", "Import", "Indesign", "Indexing", "Information",
                 "Infrastructure", "Inheritance", "Input", "Installation", "Instructing", "Intelligence", "Intellij",
                 "Intellij-Idea", "Interface", "Internet-Explorer", "Invision", "Io", "Ionic-Framework", "Ios", "Ios7",
                 "Ip", "Ipad", "Iphone", "Jar", "Java", "Java-8", "Java-Ee", "Javafx", "Javascript", "Jdbc", "Jenkins",
                 "Jest", "Join", "Joomla", "Jpa", "Jquery", "Jquery-Mobile", "Jquery-Ui", "Jsf", "Jsf-2", "Json", "Jsp",
                 "Junit", "Jupyter", "Kaggle", "Kali", "Kendo-Ui", "Keras", "Kernal", "Knockout.Js", "Kotlin",
                 "Kubernetes", "Lambda", "Language", "Language", "Laravel", "Laravel-4", "Laravel-5", "Latex", "Layout",
                 "Learning", "Linked-List", "Linq", "Linq-To-Sql", "Linux", "Linux/Unix", "Lisp", "List", "Listview",
                 "Logging", "Login", "Loops", "Lua", "Machine", "Machine-Learning", "Macos", "Magento", "Maintenance",
                 "Makefile", "Management", "Management", "Manufacturing", "Markdown", "Markup", "Math", "Mathematics",
                 "Matlab", "Matplotlib", "Matrix", "Maven", "Mechanical", "Media", "Memory", "Memory-Leaks",
                 "Memory-Management", "Menu", "Merge", "Meteor", "Methods", "Microsoft", "Middleware", "Mining",
                 "Mobile", "Mod-Rewrite", "Model", "Model-View-Controller", "Modeling", "Modems/Routers", "Modification",
                 "Module", "Mongodb", "Mongoose", "Monitoring", "Ms-Access", "Ms-Word", "Multidimensional-Array",
                 "Multithreading", "Mvvm", "Mysql", "Mysqli", "Natural", "Neo4J", "Netbeans", "Network", "Networking",
                 "Neural", "New", "Nginx", "Nhibernate", "Node", "Node.Js", "Nosql", "Notebook", "Npm",
                 "Nullpointerexception", "Numeracy", "Numpy", "Oauth", "Oauth-2.0", "Object", "Object-Oriented",
                 "Objective-C", "Office", "Oop", "Opencv", "Opengl", "Operating", "Operation", "Optimization", "Oracle",
                 "Oracle11G", "Ordering", "Orm", "Outlook", "Pagination", "Pandas", "Parallel-Processing", "Parameters",
                 "Parse-Platform", "Parsing", "Pascal", "Path", "Paypal", "Pdf", "Pdo", "Performance", "Perl",
                 "Persuasion", "Photoshop", "Php", "Phpmyadmin", "Physics", "Pivot", "Planning", "Playframework",
                 "Plot", "Plsql", "Plugins", "Pointers", "Polymorphism", "Post", "Postgresql", "Powershell",
                 "Presentation", "Primefaces", "Printing", "Problem", "Process", "Processing", "Product",
                 "Programming", "Promise", "Properties", "Proxy", "Push-Notification", "Pycharm", "Pyspark", "Python",
                 "Python-2.7", "Python-3.X", "Pytorch", "Qt", "Quantitative", "Query", "R", "Random", "Razor", "React",
                 "React-Native", "Reactjs", "Recursion", "Redirect", "Redis", "Redux", "Reflection", "Regex",
                 "Regression", "Relationship", "Repairing", "Replace", "Reporting-Services", "Reports", "Repository",
                 "Research", "Resource", "Resources", "Responsive-Design", "Rest", "Restful", "Restoration", "Reviews",
                 "Revision", "Risk", "Rpc", "Rspec", "Ruby", "Ruby-On-Rails", "Ruby-On-Rails-3", "Ruby-On-Rails-4",
                 "Saas", "Safari", "Sass", "Scala", "Scikit-Learn", "Scipy", "Scope", "Scraping", "Scratch",
                 "Scripting", "Scroll", "Scrum", "Scss", "Sdk", "Search", "Security", "Sed", "Select", "Selenium",
                 "Selenium-Webdriver", "Serialization", "Server", "Server", "Servers", "Service", "Services",
                 "Services", "Servlets", "Session", "Setup", "Sharepoint", "Shell", "Shiny", "Silverlight", "Soap",
                 "Social", "Socket", "Socket.Io", "Sockets", "Software", "Solr", "Solution", "Solving", "Sonography",
                 "Sorting", "Source", "Split", "Spring", "Spring-Boot", "Spring-Mvc", "Spring-Security", "Sql", "Sql",
                 "Sql-Server", "Sql-Server-2005", "Sql-Server-2008", "Sql-Server-2012", "Sqlite", "Ssh", "Ssis", "Ssl",
                 "Stack", "Statistical", "Statistics", "Storage", "Stored-Procedures", "String", "Struct", "Structural",
                 "Structures", "Study", "Suite", "Support", "Svg", "Svn", "Swift", "Swift3", "Swing", "Symfony",
                 "Syntax", "Systems", "Tables", "Tcl", "Tcp", "Team", "Technical", "Techniques", "Technologies",
                 "Technology", "Telecommunications", "Templates", "Tensor", "Tensorflow", "Terminal", "Test", "Testing",
                 "Text", "Tfs", "Three.Js", "Time", "Timer", "Tkinter", "Tomcat", "Toolkits", "Tools", "Training",
                 "Triggers", "Troubleshooting", "Tsql", "Twitter", "Twitter-Bootstrap", "Twitter-Bootstrap-3", "Types",
                 "Typescript", "Ubuntu", "Ui", "Uikit", "Uitableview", "Uiview", "Uiviewcontroller", "Unicode",
                 "Unit-Testing", "Unity", "Unity3D", "Unix", "Url", "Url-Rewriting", "Usability", "User",
                 "User-Interface", "Utf-8", "Uwp", "Ux", "Validation", "Variables", "Vb.Net", "Vba", "Vbscript",
                 "Vector", "Verification", "Version", "Version-Control", "Video", "View", "Vim", "Virtual", "Vision",
                 "Visual", "Visual-C++", "Visual-Studio", "Visual-Studio-2008", "Visual-Studio-2010",
                 "Visual-Studio-2012", "Visual-Studio-2013", "Visual-Studio-2015", "Visual-Studio-Code", "Vue", "Vue.Js",
                 "Vuejs2", "Wcf", "Web", "Web", "Web-Applications", "Web-Scraping", "Web-Services", "Webforms",
                 "Webpack", "Websocket", "Webview", "While-Loop", "Winapi", "Windows", "Windows-Phone-7",
                 "Windows-Phone-8", "Winforms", "Wireless", "Woocommerce", "Wordpress", "Wpf", "Writing", "Xamarin",
                 "Xamarin.Android", "Xamarin.Forms", "Xaml", "Xcode", "Xml", "Xpath", "Xslt", "Yii", "Zend-Framework",
                 "Zeppelin"]

base_url = 'https://www.indeed.com/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Using TensorFlow backend.

# %% [markdown]
# # URL creation function

# %%
def createURL(city=None, state=None, job=None, job_title=None, explvl=None, sort=None):
    """
    Takes in filters (location, search query, job title, experience level) and generates an Indeed URL
    that shows all the job postings with the specified filters
    :param city: city location
    :param state: state location
    :param job: job search query
    :param job_title: position i.e. full time, part time, etc.
    :param explvl: experience level i.e. entry level
    :param sort: jobs sorted by i.e. date
    :return: generated Indeed URL
    """

    final_url = ''
    if job is not None:
        job = job.split()
        job = '+'.join(word for word in job)
        final_url = 'jobs?q=' + job
    else:
        final_url = final_url + 'jobs?q=%22%22'

    if city is not None and state is not None:
        city = city.split()
        city = '+'.join(word for word in city)
        final_url = final_url + '&l=' + city + '%2C+' + state
    elif city is not None and state is None:
        final_url = final_url + '&l=' + city
    elif city is None and state is not None:
        final_url = final_url + '&l=' + state

    if job_title is not None:
        job_title = job_title.split()
        job_title = ''.join(word for word in job_title)
        final_url = final_url + '&jt=' + job_title

    if explvl is not None:
        explvl = explvl.split()
        explvl = '_'.join(word for word in explvl)
        final_url = final_url + '&explvl=' + explvl

    if sort is not None:
        final_url = final_url + '&sort=' + sort

    final_url = final_url + "&start={}"
    final_url = base_url + final_url
    print("Base URL for web scraping: " + final_url)

    return final_url

# %% [markdown]
# # Field extraction functions

# %%
def getRoleTitle(job):
    """
    Takes job card and returns the job title
    :param job: job card being looked at
    :return: title for job card
    """

    search = [job.find(name="a", attrs={"data-tn-element": "jobTitle"})]
    # print(search)
    try:
        return search[0]["title"]
    except:
        return "N/A"


def getIndeedJobListingURL(job):
    """
    Takes job card and returns url
    :param job: job being looked at
    :return: url for job card
    """

    search = [job.find("div", {"class": "title"})]
    try:
        return base_url + search[0].a['href']
    except:
        return "N/A"


def getCompany(job):
    """
    Takes job card and returns the company
    :param job: job being looked at
    :return: company of job card
    """

    search = [job.find("span", {"class": "company"})]
    try:
        if search[0].text.strip() is None:
            return search[0].find(name="a", attrs={"data-tn-element": "companyName"}).text.strip()
        else:
            return search[0].text.strip()
    except:
        return "N/A"


def getFullLocation(job):
    """
    Takes in a job card to parse location. This function is sent to getLocationArea() to parse info
    - need to handle edge cases like encountering 'Remote', 'Washington State', 'United States',
    :param job: job being looked at
    :return: full location of job card
    """

    search = [job.find(re.compile(r"(span|div)"), {"class": "location"})]
    try:
        return search[0].text
    except:
        return "N/A"


def getLocationState(job):
    """
    Takes job card and returns location state
    :param job: job being looked at
    :return: location state of job card
    """

    search = [job.find(re.compile(r"(span|div)"), {"class": "location"})]
    # print(search)
    loc = word_tokenize(search[0].text)
    try:
        if len(loc) >= 3:
            return loc[2]
        else:
            return "N/A"
    except:
        return "N/A"


def getLocationCity(job):
    """
    Takes job card and returns the location city
    #need to handle "washington state, remote, etc
    :param job: job being looked at
    :return: location city of job card
    """

    search = [job.find(re.compile(r"(span|div)"), {"class": "location"})]
    loc = word_tokenize(search[0].text)
    try:
        if len(loc) >= 3:
            return loc[0]
        else:
            return "N/A"
    except:
        return "N/A"


def getLocationZipCode(job):
    """
    Takes job card and returns location zip code
    :param job: job being looked at
    :return: location zip code from job card
    """

    search = [job.find(re.compile(r"(span|div)"), {"class": "location"})]
    loc = word_tokenize(search[0].text)
    try:
        if len(loc) == 4:
            return loc[3]
        else:
            return "N/A"
    except:
        return "N/A"


def getLocationArea(l):
    """
    Takes full location string from getFullLocation() and extracts location area
    :param l: full location
    :return: area from job card
    """

    first = l.find('(')
    last = l.find(')')
    if first != -1 and last != -1:
        return l[first:last + 1]
    else:
        return "N/A"


def getSalary(job):
    """
    Takes a job card and parses the salary string
    :param job: job being looked at
    :return: salary from job card
    """

    search = [job.find("span", {"class": "salary no-wrap"})]
    try:
        if not search:
            return "N/A"
        else:
            return search[0].text.strip()
    except:
        return "N/A"


def getMinimumSalary(l):
    """
    Takes full salary to parse minimum salary
    :param l: full salary
    :return: min salary from job card
    """

    pattern = r"(?:[\£\$\€]{1}[,\d]+.?\d*)"
    l = l.replace(".00", "")
    salary = re.findall(pattern, l)
    try:
        return salary[0]
    except:
        return "N/A"


def getMaximumSalary(l):
    """
    Takes full salary to parse maximum salary
    :param l: full salary
    :return: max salary from job card
    """

    pattern = r"(?:[\£\$\€]{1}[,\d]+.?\d*)"
    l = l.replace(".00", "")
    salary = re.findall(pattern, l)
    try:
        return salary[1]
    except:
        return "N/A"


def getSalaryTimeUnits(l):
    """
    Takes full salary and parses for time unit
    :param l: full salary
    :return: time units from job card (for salary)
    """

    if 'hour' in l:
        return 'Hourly'
    elif 'day' in l:
        return 'Daily'
    elif 'week' in l:
        return 'Weekly'
    elif 'year' in l:
        return 'Yearly'
    else:
        return 'N/A'


def getShortDescription(job):
    """
    Takes job card and parses the short description for job postings
    :param job: job being looked at
    :return: short description from job card
    """

    search = [job.find("div", {"class": "summary"})]
    try:
        return search[0].text.strip()
    except:
        return "N/A"


def getHasExpressApply(job):
    """
    Takes job card and parses express apply option
    :param job: job being looked at
    :return: express apply from job card (if there is express apply, otherwise returns N/A)
    """

    search = [job.find("div", {"class": "iaWrapper"})]
    try:
        if search is None:
            return "N/A"
        else:
            return search[0].div.span.text.strip()
    except:
        return "N/A"


def getIsSponsored(job):
    """
    Takes job card and parses sponsored option
    :param job: job being looked at
    :return: sponsor of job card (if there is one, otherwise returns N/A)
    """

    search = [job.find("span", {"class": "sponsoredGray"})]
    try:
        if not search:
            return "N/A"
        else:
            return search[0].text
    except:
        return "N/A"


def getExperienceLevel(url):
    """
    Takes the url (from creation) and finds experience level
    :param url: url we're looking at
    :return: exp lvl of job
    """

    if 'entry_level' in url:
        return "Entry Level"
    elif 'mid_level' in url:
        return "Mid Level"
    elif 'senior_level' in url:
        return "Senior Level"
    else:
        return "N/A"


def getJobType(url):
    """
    Takes the url (from creation) and finds job type
    :param url: url we're looking at
    :return: job type of job
    """

    if 'fulltime' in url:
        return "Full-time"
    elif 'internship' in url:
        return "Internship"
    elif 'parttime' in url:
        return "Part-time"
    elif 'temporary' in url:
        return "Temporary"
    elif 'contract' in url:
        return "Contract"
    elif 'commission' in url:
        return "Commission"
    else:
        return "N/A"


def getResponsiveEmployer(job):
    """
    Takes job card and parses responsive employer
    :param job: job being looked at it
    :return: responsive employer from job card (if employer is responsive, otherwise returns N/A)
    """

    search = [job.find("div", {"class": "serp-ResponsiveEmployer"})]
    try:
        return search[0].text
    except:
        return "N/A"


# def getCmpID(l, jobMapCount):
#     """
#     Takes jobmap and appends company id
#     :param l: jobmap
#     :param jobCount: iteration number for loop (number of jobs on a page)
#     :return: list of company ids
#     """
#
#     ret = []
#     for items in l:
#         ret.append(items['cmpid'])
#     checkRet(ret, getCmpID.__name__, jobMapCount)
#     return ret
#
#
# def getCmpEsc(l, jobMapCount):
#     """
#     Takes jobmap and appends cmpesc
#     :param l: jobmap
#     :param jobMapCount: iteration number for loop
#     :return: list of cmpesc
#     """
#
#     ret = []
#     for items in l:
#         ret.append(items['cmpesc'])
#     checkRet(ret, getCmpEsc.__name__, jobMapCount)
#     return ret
#
#
# def getSrcName(l, jobMapCount):
#     """
#     Takes jobmap and appends srcname
#     :param l: jobmap
#     :param jobMapCount: iteration number for loop
#     :return: list of srcname
#     """
#
#     ret = []
#     for items in l:
#         ret.append(items['srcname'])
#     checkRet(ret, getSrcName.__name__, jobMapCount)
#     return ret


def getJobID(job):
    """
    Takes job card and parses for each job listing's ID
    :param job: job being looked at
    :return: job ID from job card
    """

    try:
        return job.get('id')
    except:
        return "N/A"

# %%
# check if the search 0 (meaning indeed changed their html var names (wont find them)
# if they kept same names & changed data inside -> think about it
# tells us if indeed changed job posting amts too i.e they start displaying n>10 or n<10
# can add like a global error count and if it > 2 = stop program

# def checkRet(l, check, jobMapCount):
#     # print("HTML might have changed. Check function:", check, "--- retLen:", len(l))
#     if len(l) != jobMapCount:
#         print("HTML might have changed. Check function: ", check, ".")
#     pass

# %% [markdown]
# # Web scraping functions

# %%
def scrape(soup):
    """
    Takes soup obj -> sends to helper functions to obtain info for our data frame
    :param soup: soup object
    :return: roleTitle,company,fullLocation,locationState,
           locationCity,locationZipCode,locationArea,
           salary,minSalary,maxSalary,salaryTimeUnits,
           shortDesc, fullDesc, expressApply,sponsor,indeedURL,
           expLevel,responsiveEmployer,jobType, jobID
    """
    search = soup.find_all("div", {"class": "jobsearch-SerpJobCard unifiedRow row result"})
    print("Number of jobs on page: ", len(search))
    roleTitle = []
    company = []
    fullLocation = []
    locationState = []
    locationCity = []
    locationZipCode = []
    locationArea = []
    salary = []
    minSalary = []
    maxSalary = []
    salaryTimeUnits = []
    shortDesc = []
    expressApply = []
    sponsor = []
    indeedURL = []
    expLevel = []
    jobType = []
    responsiveEmployer = []
    jobID = []

    if search is None:
        return  # might need to return all the lists
    else:
        for job in search:
            roleTitle.append(getRoleTitle(job))
            company.append(getCompany(job))
            locationState.append(getLocationState(job))
            locationCity.append(getLocationCity(job))
            locationZipCode.append(getLocationZipCode(job))
            locationArea.append(getLocationArea(getFullLocation(job)))
            minSalary.append(getMinimumSalary(getSalary(job)))
            maxSalary.append(getMaximumSalary(getSalary(job)))
            salaryTimeUnits.append(getSalaryTimeUnits(getSalary(job)))
            shortDesc.append(getShortDescription(job))
            expressApply.append(getHasExpressApply(job))
            sponsor.append(getIsSponsored(job))
            indeedURL.append(getIndeedJobListingURL(job))
            expLevel.append(getExperienceLevel(URL))  # uses url
            jobType.append(getJobType(URL))  # uses url
            responsiveEmployer.append(getResponsiveEmployer(job))
            jobID.append(getJobID(job))

        return roleTitle, company, fullLocation, locationState, \
               locationCity, locationZipCode, locationArea, \
               salary, minSalary, maxSalary, salaryTimeUnits, \
               shortDesc, expressApply, sponsor, indeedURL, \
               expLevel, jobType, responsiveEmployer, jobID

# %%
def jobScrape(url_list):
    jobCount = 0
    app_urls = []
    descriptions = []
    last_updated = []
    has_bullets = []
    gen_bullet_points = []
    good_to_have_bullet_points = []
    required_bullet_points = []

    gen_associated_skills = []
    good_to_have_associated_skills = []
    required_associated_skills = []
    for url in url_list:
        print("Working on job #", jobCount + 1)
        print("URL being scraped: ", url, '\n')
        required_skills = []
        good_to_have_skills = []
        skills = []

        required_bullets = []
        good_to_have_bullets = []
        bullets = []
        try:
            html = requests.get(url, timeout=3)  # connects to url
            #print(html.status_code)
            html.raise_for_status()
            time.sleep(1.5)
            soup = BeautifulSoup(html.content, 'html.parser')  # gets html
            description = soup.find(id='jobDescriptionText')
            descriptions.append(description)

            app_url = soup.find_all('a', string='Apply On Company Site')
            if not app_url:
                app_urls.append("N/A")
            else:
                app_urls.append(app_url[0].get('href'))

            date = soup.find_all("div", {"class": "jobsearch-JobMetadataFooter"})
            updated = date[0].text
            number = re.findall(r'\d+', updated)
            # print(updated)
            if "Just posted" in updated or "Today" in updated:
                last_updated.append(datetime.today())
            elif "day" in updated and number:
                last_updated.append(datetime.today() - timedelta(days=int(number[0])))
            elif number and int(number[0]) == 30:
                last_updated.append(datetime.today() - timedelta(days=30))
            else:
                last_updated.append("N/A")

            tags_content = [str(tag) for tag in description.find_all()]
            ul_tag = ''
            for tag in tags_content:
                if ul_tag != '' and tag != ul_tag:  # after first iteration, skip to found ul tag
                    continue
                b_instances = tag.count("<b>")
                p_instances = tag.count("<p>")
                ul_tag = ''
                if any(word in tag.lower() for word in gen_headers) and (((tag.lower().startswith('<b>')
                                                                           and tag.lower().endswith(
                            '</b>')) and b_instances == 1 and p_instances == 0) or
                                                                         ((tag.lower().startswith(
                                                                             '<p>') and tag.lower().endswith(
                                                                             '</p>'))) and b_instances == 0 and
                                                                         p_instances == 1):
                    start = tags_content.index(tag)
                    while ul_tag is '':
                        if start == len(tags_content) - 1:
                            break
                        start += 1
                        if tags_content[start].startswith("<ul>") and tags_content[start].endswith("</ul>"):
                            ul_tag = tags_content[start]
                    if ul_tag != '':
                        if any(word in tag.lower() for word in required_headers):
                            required_bullets.append(ul_tag)
                        elif any(word in tag.lower() for word in good_to_have_headers):
                            good_to_have_bullets.append(ul_tag)
                        else:
                            bullets.append(ul_tag)

            appendBulletsAndSkills(required_bullets, required_bullet_points, required_skills)
            appendBulletsAndSkills(good_to_have_bullets, good_to_have_bullet_points, good_to_have_skills)
            appendBulletsAndSkills(bullets, gen_bullet_points, skills)
            checkBullets(required_bullets, good_to_have_bullets, bullets, has_bullets, description, skills)

            if not required_skills:
                required_associated_skills.append("N/A")
            else:
                required_associated_skills.append(required_skills)
            if not good_to_have_skills:
                good_to_have_associated_skills.append("N/A")
            else:
                good_to_have_associated_skills.append(good_to_have_skills)
            if not skills:
                gen_associated_skills.append("N/A")
            else:
                gen_associated_skills.append(skills)
        except requests.exceptions.HTTPError as errh:
            print("Http error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout error:", errt)
        except requests.exceptions.RequestException as err:
            print("Error (unid):", err)
        jobCount += 1
        
    return app_urls, descriptions, gen_bullet_points, good_to_have_bullet_points, required_bullet_points, has_bullets, \
           gen_associated_skills, good_to_have_associated_skills, required_associated_skills, last_updated


def appendBulletsAndSkills(small_bullets, big_bullets, skills_list):
    """
    Checks if there are bullet points or not. If there are bullet points, appends the bullet points and then pulls
    the skills from them.
    :param small_bullets: bullet point list to be appended to the the list of all the jobs' bullet points
    :param big_bullets: bullet points to be appended to the data frame
    :param skills_list: skills associated with the jobs' bullet points (if it has any)
    :return: nothing
    """
    if not small_bullets:
        big_bullets.append("N/A")
    else:
        big_bullets.append(small_bullets)
        for bullet in small_bullets:
            clean_bullet = BeautifulSoup(str(bullet), features='lxml').get_text().lower()
            for skill in skills_labels:
                if skill == 'C++' or skill == 'C#':
                    skill_pattern = re.compile(re.escape(skill), re.IGNORECASE)
                else:
                    skill_pattern = re.compile(r"\b" + re.escape(skill) + r"\b", re.IGNORECASE)
                if skill_pattern.findall(clean_bullet) and skill not in skills_list:
                    skills_list.append(skill)


def checkBullets(required_bullets, good_to_have_bullets, bullets, has_bullets, description, skills):
    """
    Checks if there are any bullet points. If not, pulls the skills from the entire description and appends "False" to
    the has bullet points list. If there are bullet points, appends "True" to the has bullet points list.
    :param required_bullets: bullet points that has a heading indicating that they are required
    :param good_to_have_bullets: bullet points that has a heading indicating that they are good to have
    :param bullets: bullet points that has a heading indicating neither good to have or required.
    :param has_bullets: list that indicates if a job description has bullet points or not.
    :param description: entire HTML description of the job listing
    :param skills: list of skills pulled from the entire description
    :return: nothing
    """
    if not required_bullets and not good_to_have_bullets and not bullets:
        has_bullets.append("False")
        clean_description = BeautifulSoup(str(description), features='lxml').get_text().lower()
        for skill in skills_labels:
            if skill == 'C++' or skill == 'C#':
                skill_pattern = re.compile(re.escape(skill), re.IGNORECASE)
            else:
                skill_pattern = re.compile(r"\b" + re.escape(skill) + r"\b", re.IGNORECASE)
            if skill_pattern.findall(clean_description) and skill not in skills:
                skills.append(skill)
    else:
        has_bullets.append("True")

# %% [markdown]
# # Extracts total number of jobs and pages from a query

# %%
def get_max_results(url):
    """
    Gets the total number of jobs and pages found from a search on Indeed.
    :param url: indeed URL search
    :return: total number of jobs found
    """

    # page_response = requests.get(url, timeout=3)
    # soup = BeautifulSoup(page_response.content, 'html.parser')

    html = urlopen(url)  # connects to url
    soup = BeautifulSoup(html.read(), features="lxml")  # gets html

    num_jobs_area = soup.find(id='searchCountPages').text.strip()
    # print(num_jobs_area)
    job_numbers = re.findall(r'\d+', num_jobs_area)  # Extract the total jobs found from the search result

    if len(job_numbers) >= 3:  # Have a total number of jobs greater than 1000
        total_num_jobs = (int(job_numbers[1]) * 1000) + int(job_numbers[2])
    else:
        total_num_jobs = int(job_numbers[1])

    print("Number of jobs found: " + str(total_num_jobs) + " jobs" + "\n")
    numPages = round(total_num_jobs / 10) - 1
    return numPages

# %% [markdown]
# # Run scraping function to pull information from jobs

# %%
df = pd.DataFrame()
jobDescription_df = pd.DataFrame()
URL = createURL(city=None, state="WA", job=None, job_title="part time", explvl="entry level", sort="date")
maxResults = get_max_results(URL)
http = urllib3.PoolManager()

t0 = time.time()
for pages in range(maxResults):
    t1 = time.time()
    nextPage = URL.format(pages * 10)
    print("Working on page: ", pages + 1)
    print("URL being scraped: ", nextPage)
    try:
        html = urlopen(nextPage)  # connects to url
        soup = BeautifulSoup(html.read(), features="lxml")  # gets html

        roleTitle, company, fullLocation, locationState, \
        locationCity, locationZipCode, locationArea, \
        salary, minSalary, maxSalary, salaryTimeUnits, \
        shortDesc, expressApply, sponsor, indeedURL, \
        expLevel, jobType, responsiveEmployer, jobID = scrape(soup)

        newData = pd.DataFrame({
            'RoleTitle': roleTitle,
            'Company': company,
            'LocationState': locationState,
            'LocationCity': locationCity,
            'LocationZipCode': locationZipCode,
            'LocationArea': locationArea,
            'MinimumSalary': minSalary,
            'MaximumSalary': maxSalary,
            'SalaryTimeUnits': salaryTimeUnits,
            'ShortDescription': shortDesc,
            'HasExpressApply': expressApply,
            'IsSponsored': sponsor,
            'IndeedJobListingURL': indeedURL,
            'ExperienceLevel': expLevel,
            'JobType': jobType,
            'ResponsiveEmployer': responsiveEmployer,
            'JobID': jobID
        })

        df = df.append(newData)

        print("Processing iteration: {} || Completion: {}% ||".format(pages, 100 * pages // maxResults), end="")
        t2 = time.time()
        print(" Iteration time: {}s || Total time: {}s".format(round(t2 - t1, 3), round(t2 - t0, 3)) + "\n")


    except urllib.error.URLError as errurl:
            print("URL Error: ", errurl)
    except urllib.error.HTTPError as errh:
        print("HTTP Error: ", errh)
    except urllib.error.ContentTooShortError as errc:
        print("Content Error: ", errc)
    except:
        df.to_csv("indeedJobs.csv", index=False)

df = df.drop_duplicates(subset="IndeedJobListingURL", keep=False) # remove duplicates
df.to_csv("indeedJobs.csv", index=False) # export dataframe to csv
# Out:
# Base URL for web scraping: https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start={}
# Number of jobs found: 17071 jobs
#
# Working on page:  1
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=0
# Number of jobs on page:  17
# Processing iteration: 0 || Completion: 0% || Iteration time: 0.615s || Total time: 0.615s
#
# Working on page:  2
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=10
# Number of jobs on page:  10
# Processing iteration: 1 || Completion: 0% || Iteration time: 0.536s || Total time: 1.151s
#
# Working on page:  3
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=20
# Number of jobs on page:  16
# Processing iteration: 2 || Completion: 0% || Iteration time: 0.619s || Total time: 1.77s
#
# Working on page:  4
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=30
# Number of jobs on page:  10
# Processing iteration: 3 || Completion: 0% || Iteration time: 0.507s || Total time: 2.277s
#
# Working on page:  5
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=40
# Number of jobs on page:  18
# Processing iteration: 4 || Completion: 0% || Iteration time: 0.715s || Total time: 2.993s
#
# Working on page:  6
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=50
# Number of jobs on page:  15
# Processing iteration: 5 || Completion: 0% || Iteration time: 0.608s || Total time: 3.601s
#
# Working on page:  7
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=60
# Number of jobs on page:  18
# Processing iteration: 6 || Completion: 0% || Iteration time: 0.573s || Total time: 4.174s
#
# Working on page:  8
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=70
# Number of jobs on page:  10
# Processing iteration: 7 || Completion: 0% || Iteration time: 0.512s || Total time: 4.686s
#
# Working on page:  9
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=80
# Number of jobs on page:  18
# Processing iteration: 8 || Completion: 0% || Iteration time: 0.624s || Total time: 5.31s
#
# Working on page:  10
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=90
# Number of jobs on page:  18
# Processing iteration: 9 || Completion: 0% || Iteration time: 0.596s || Total time: 5.907s
#
# Working on page:  11
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=100
# Number of jobs on page:  10
# Processing iteration: 10 || Completion: 0% || Iteration time: 0.493s || Total time: 6.4s
#
# Working on page:  12
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=110
# Number of jobs on page:  18
# Processing iteration: 11 || Completion: 0% || Iteration time: 0.612s || Total time: 7.012s
#
# Working on page:  13
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=120
# Number of jobs on page:  15
# Processing iteration: 12 || Completion: 0% || Iteration time: 0.538s || Total time: 7.55s
#
# Working on page:  14
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=130
# Number of jobs on page:  15
# Processing iteration: 13 || Completion: 0% || Iteration time: 0.586s || Total time: 8.136s
#
# Working on page:  15
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=140
# Number of jobs on page:  15
# Processing iteration: 14 || Completion: 0% || Iteration time: 0.93s || Total time: 9.067s
#
# Working on page:  16
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=150
# Number of jobs on page:  16
# Processing iteration: 15 || Completion: 0% || Iteration time: 0.562s || Total time: 9.629s
#
# Working on page:  17
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=160
# Number of jobs on page:  10
# Processing iteration: 16 || Completion: 0% || Iteration time: 0.523s || Total time: 10.152s
#
# Working on page:  18
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=170
# Number of jobs on page:  15
# Processing iteration: 17 || Completion: 0% || Iteration time: 0.594s || Total time: 10.746s
#
# Working on page:  19
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=180
# Number of jobs on page:  17
# Processing iteration: 18 || Completion: 1% || Iteration time: 0.607s || Total time: 11.353s
#
# Working on page:  20
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=190
# Number of jobs on page:  10
# Processing iteration: 19 || Completion: 1% || Iteration time: 0.771s || Total time: 12.124s
#
# Working on page:  21
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=200
# Number of jobs on page:  18
# Processing iteration: 20 || Completion: 1% || Iteration time: 0.575s || Total time: 12.699s
#
# Working on page:  22
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=210
# Number of jobs on page:  18
# Processing iteration: 21 || Completion: 1% || Iteration time: 0.595s || Total time: 13.295s
#
# Working on page:  23
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=220
# Number of jobs on page:  10
# Processing iteration: 22 || Completion: 1% || Iteration time: 0.492s || Total time: 13.787s
#
# Working on page:  24
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=230
# Number of jobs on page:  18
# Processing iteration: 23 || Completion: 1% || Iteration time: 0.619s || Total time: 14.406s
#
# Working on page:  25
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=240
# Number of jobs on page:  18
# Processing iteration: 24 || Completion: 1% || Iteration time: 0.653s || Total time: 15.059s
#
# Working on page:  26
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=250
# Number of jobs on page:  18
# Processing iteration: 25 || Completion: 1% || Iteration time: 0.617s || Total time: 15.677s
#
# Working on page:  27
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=260
# Number of jobs on page:  17
# Processing iteration: 26 || Completion: 1% || Iteration time: 0.602s || Total time: 16.279s
#
# Working on page:  28
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=270
# Number of jobs on page:  15
# Processing iteration: 27 || Completion: 1% || Iteration time: 0.561s || Total time: 16.84s
#
# Working on page:  29
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=280
# Number of jobs on page:  16
# Processing iteration: 28 || Completion: 1% || Iteration time: 0.563s || Total time: 17.403s
#
# Working on page:  30
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=290
# Number of jobs on page:  18
# Processing iteration: 29 || Completion: 1% || Iteration time: 0.628s || Total time: 18.032s
#
# Working on page:  31
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=300
# Number of jobs on page:  17
# Processing iteration: 30 || Completion: 1% || Iteration time: 0.578s || Total time: 18.61s
#
# Working on page:  32
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=310
# Number of jobs on page:  15
# Processing iteration: 31 || Completion: 1% || Iteration time: 0.556s || Total time: 19.166s
#
# Working on page:  33
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=320
# Number of jobs on page:  17
# Processing iteration: 32 || Completion: 1% || Iteration time: 0.656s || Total time: 19.822s
#
# Working on page:  34
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start=330
# Number of jobs on page:  16
# Processing iteration: 33 || Completion: 1% || Iteration time: 0.601s || Total time: 20.423s
#
# Working on page:  35
# URL being scraped:  https://www.indeed.com/jobs?q=%22%22&l=WA&jt=parttime&explvl=entry_level&sort=date&start
# df_with_data = pd.read_csv('indeedJobs.csv')
df_with_data = pd.read_csv('/content/gdrive/My Drive/dsci/Data/indeedJobs_WA_fulltime_entrylevel_date_part1.csv')
# print(df_with_data)
job_titles = df_with_data["RoleTitle"]
df_job_titles = pd.DataFrame(job_titles, columns=['RoleTitle'])
df_job_titles.to_csv("jobTitles.csv", index=False)

jobTitlesDF = pd.read_csv("jobTitles.csv")
generalJobTitlesDF = pd.read_csv("/content/gdrive/My Drive/dsci/Job_title.csv")

classifiedJobsDF = pd.DataFrame(columns = ['RoleTitle', 'ClassifiedJobRoles'])
classifiedJobsDF['RoleTitle'] = list(jobTitlesDF['RoleTitle'])


jobTitlesDF['RoleTitle'] = data_helpers.removeStops(jobTitlesDF)
labeledJobs,unlabeledJobs = data_helpers.genLabels2(jobTitlesDF,generalJobTitlesDF)

#unpickle tokenizer
pickle_in1 = open('/content/gdrive/My Drive/dsci/tokenizer.pkl','rb')
tokenizer = pickle.load(pickle_in1)
pickle_in2 = open('/content/gdrive/My Drive/dsci/vocab_size.pkl','rb')
vocab_size = pickle.load(pickle_in2)
pickle_in3 = open('/content/gdrive/My Drive/dsci/maxLen.pkl','rb')
maxLen = pickle.load(pickle_in3)
pickle_in1.close()
pickle_in2.close()
pickle_in3.close()

def t2s(tokenizer,string):
    #print('init x test/train tokens')
    ret = tokenizer.texts_to_sequences(string)
    return ret
  
def padSequence(string, maxLen, defaultPadding = 'post'):
    ret = keras.preprocessing.sequence.pad_sequences(string,maxlen=maxLen,padding=defaultPadding)
    return ret

def predict_on_Model(model, string, tokenizer,maxLen):
    testSamplesTokens = tokenizer.texts_to_sequences(string)
    # #print('test tokens: ', testSamplesTokens)
    # #print('test tokens: ',testSamplesTokens.shape)
    tsPadded = padSequence(testSamplesTokens,maxLen)

    #print('predicting')
    prediction = model.predict(tsPadded)

    #print(prediction)
    return prediction
  
def evaluateModel(model,x,y):
    loss, accuracy = model.evaluate(x,y,verbose=0)
    print('Test Accuracy: %f' % (accuracy*100))
    print('Test Loss: %f' % (loss*100))
    
    
def getParentTitle(predicted,generalJobTitlesDF):
  for currList in allMyJobLabels:
    for jobs in currList[1:]:
      if predicted == jobs:
        #print('--------found for ',predicted, ' in ', currList[1:])
        finalJobRole = currList[0]
        return finalJobRole, True
  return predicted, False

x_train, x_test, y_train, y_test = train_test_split(jobTitlesDF["RoleTitle"], labeledJobs,shuffle=True, test_size=.2)


x_train_tokens = t2s(tokenizer,x_train)
x_test_tokens = t2s(tokenizer, x_test)

x_train_pad = padSequence(x_train_tokens,maxLen)
x_test_pad = padSequence(x_test_tokens,maxLen)

y_train_hot = keras.utils.to_categorical(y_train,151)
y_test_hot = keras.utils.to_categorical(y_test,151)

model = keras.models.load_model('/content/gdrive/My Drive/dsci/modelTest.h5')

text_samples = jobTitlesDF['RoleTitle'].str.lower().values

softwareEngineer = ['Software Engineer',58,19,41,135,27,14,42,59,69,71,129,80,139,104,114,127,78,56,20,34,70]
webDeveloper = ['Web Developer',116,91,115]
networkEngineer = ['Network Engineer',67,40,44,51,79,99]
it = ['IT',0,5,11,94,107,123,31,93,2,4,12,18,33,36,54,106,108,45,38,128,46]
dataEngineer = ['Data Engineer',102,101,90,119,32,112,97,3,120]
analyst = ['Analyst',138,65,7,21,43,57,77,113,122]
ui_ux = ['UI/UX',22,76,75,82,118,145,95,117,146,50,124,111]
dataScientist = ['Data Scientist',39,85]
cyberSecurity = ['Cyber Security',98,92,24,52]
testEngineer = ['Test Engineer',105,55,23]
allMyJobLabels = [softwareEngineer,webDeveloper, networkEngineer,it,dataEngineer, ui_ux,dataScientist,analyst,cyberSecurity,testEngineer]

classifiedJobs = []
prediction = predict_on_Model(model,text_samples,tokenizer,maxLen)
y_class = prediction.argmax(axis=-1)-2
for preds,job in zip(y_class,text_samples):
  output,choice = getParentTitle(preds,generalJobTitlesDF)
  if output == 148:
    output = 149
    print("input:",job, '-> pred: ', generalJobTitlesDF['job_title'][output], "[",preds,"]")
    classifiedJobs.append(generalJobTitlesDF['job_title'][output])
  elif choice == True:
    print("input:",job, '-> pred: ', output, "[",preds,"]")
    classifiedJobs.append(output)
  else:
    print("input3:",job, '-> pred: ', generalJobTitlesDF['job_title'][output], "[",preds,"]")
    classifiedJobs.append(output)
    
classifiedJobsDF['ClassifiedJobRoles'] = classifiedJobs
# print(classifiedJobsDF)

# combined_dfs = pd.merge(df, classifiedJobsDF, on='RoleTitle', how='left') #combine original data set and predicted job roles
combined_dfs = pd.merge(df_with_data, classifiedJobsDF, on='RoleTitle', how='left') #combine original data set and predicted job roles
# combined_dfs.to_csv("all_job_roles.csv", index=None)

combined_dfs = combined_dfs[combined_dfs.ClassifiedJobRoles != 'unknown'] #remove unknowns
# print(type(classifiedJobsDF.ClassifiedJobRoles[126]))
column = list(combined_dfs.ClassifiedJobRoles)
# print(column)
for role in column: #remove numbers
  if isinstance(role, np.integer):
    combined_dfs = combined_dfs[combined_dfs.ClassifiedJobRoles != role]

combined_dfs = combined_dfs.drop_duplicates(subset="IndeedJobListingURL", keep=False) # remove duplicates
# Out:
#                                               RoleTitle  ...                JobID
# 0                                 Data Entry Specialist  ...   p_bc9052bad36d7b4d
# 1                           Customer Support Specialist  ...   p_d4d6739c084ed653
# 2                         Clerical / Data Entry / Admin  ...   p_361d81c465c8f285
# 3                                          Store Worker  ...   p_9144e4728b3cae0e
# 4                                Subway Sandwich Artist  ...   p_ff19feb1498232fd
# 5                           Branch Office Administrator  ...   p_f4e6a97b60e0cead
# 6                                      Office Assistant  ...   p_cd11a01ba1bc01c4
# 7                                  Accounting Assistant  ...   p_6c04a5b568cc7578
# 8                               Retail Sales Consultant  ...   p_a64e9f9790022d5a
# 9                   Front Desk- Galbraith Tennis Center  ...   p_39ee416c6ef89537
# 10                                Warehouse Team Member  ...  pj_c01f14388b8f36e7
# 11                   Front Desk / Insurance Coordinator  ...  pj_b5be2f6242afc95e
# 12                                Assembler Power Plant  ...  pj_50d2fd72b6bcf9ec
# 13                                         Bakery clerk  ...  pj_8f48323887201483
# 14                                  Assembler Installer  ...  pj_bcb819ce37687052
# 15               30104; 029; Assembler Inst Elec Syst B  ...  pj_f56f8a0e8d287028
# 16    Warehouse Team Member (Seasonal, Part Time, Fl...  ...  pj_603e8a80c007312e
# 17                      Customer Service Representative  ...   p_50ca7e131099c5d4
# 18    Warehouse Team Member (Seasonal, Part Time, Fl...  ...  pj_603e8a80c007312e
# 19    Warehouse Team Member - (Dupont, Washington, U...  ...  pj_703ba3d146279c6f
# 20                   Front Desk / Insurance Coordinator  ...  pj_b5be2f6242afc95e
# 21                                Warehouse Team Member  ...  pj_c01f14388b8f36e7
# 22                                  Assembler Installer  ...  pj_bcb819ce37687052
# 23                                  Warehouse Associate  ...  pj_38afd2fd06af1ac2
# 24                                Assistant Head Grower  ...  pj_4460f1b30c12d338
# 25                                               Server  ...   p_24e172eb8aba3e26
# 26                   Front Desk / Insurance Coordinator  ...   p_b5be2f6242afc95e
# 27                     Customer Experience Rep (Repair)  ...   p_8dc1cb1bfd92ccb8
# 28                              Day Warehouse Associate  ...   p_91e95d0c7f6a82d4
# 29                                   Service Consultant  ...   p_ad1b1a72b2b065cd
# ...                                                 ...  ...                  ...
# 9317                                Assembler Installer  ...  pj_bcb819ce37687052
# 9318                                Warehouse Associate  ...  pj_38afd2fd06af1ac2
# 9319                              Assistant Head Grower  ...  pj_4460f1b30c12d338
# 9320                              Assistant Head Grower  ...  pj_4460f1b30c12d338
# 9321                              Warehouse Team Member  ...  pj_c01f14388b8f36e7
# 9322                      Project Managers - All Levels  ...  pj_95226cf3ab7b7875
# 9323                  Call Center Treatment Coordinator  ...  pj_615ea15965c444ea
# 9324                              Cargo Handlers / Dock  ...  pj_09c6aa3a65a3aeec
# 9325                                Assembler Installer  ...  pj_bcb819ce37687052
# 9326             30104; 029; Assembler Inst Elec Syst B  ...  pj_f56f8a0e8d287028
# 9327                              Warehouse Team Member  ...  pj_c01f14388b8f36e7
# 9328                                Assembler Installer  ...  pj_bcb819ce37687052
# 9329  Warehouse Team Member (Seasonal, Part Time, Fl...  ...  pj_603e8a80c007312e
# 9330                              Assistant Head Grower  ...  pj_4460f1b30c12d338
# 9331             30104; 029; Assembler Inst Elec Syst B  ...  pj_f56f8a0e8d287028
# 9332                              Warehouse Team Member  ...  pj_c01f14388b8f36e7
# 9333  Warehouse Team Member (Part-Time, Seasonal)-(R...  ...  pj_bfcf876f0bc6c027
# 9334                                Assembler Installer  ...  pj_bcb819ce37687052
# 9335                              Assistant Head Grower  ...  pj_4460f1b30c12d338
# 9336                              Assistant Head Grower  ...  pj_4460f1b30c12d338
# 9337                              Warehouse Team Member  ...  pj_c01f14388b8f36e7
# 9338                      Project Managers - All Levels  ...  pj_95226cf3ab7b7875
# 9339  Warehouse Team Member (Seasonal, Part-Time, Fl...  ...  pj_5b979031d7923d61
# 9340                              Cargo Handlers / Dock  ...  pj_09c6aa3a65a3aeec
# 9341                                Assembler Installer  ...  pj_bcb819ce37687052
# 9342                              Assembler Power Plant  ...  pj_50d2fd72b6bcf9ec
# 9343                              Warehouse Team Member  ...  pj_c01f14388b8f36e7
# 9344                                Assembler Installer  ...  pj_bcb819ce37687052
# 9345                              Assistant Head Grower  ...  pj_4460f1b30c12d338
# 9346             30104; 029; Assembler Inst Elec Syst B  ...  pj_f56f8a0e8d287028
#
# [9347 rows x 17 columns]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Predicting job role for  data entry specialist ...
# input3: data entry specialist -> pred:  specialist [ 125 ]
# Predicting job role for  customer support specialist ...
# input: customer support specialist -> pred:  IT [ 36 ]
# Predicting job role for  clerical data entry admin ...
# input: clerical data entry admin -> pred:  Data Engineer [ 120 ]
# Predicting job role for  store worker ...
# input3: store worker -> pred:  technician [ 126 ]
# Predicting job role for  subway sandwich artist ...
# input3: subway sandwich artist -> pred:  technician [ 126 ]
# Predicting job role for  branch office administrator ...
# input3: branch office administrator -> pred:  technician [ 126 ]
# Predicting job role for  office assistant ...
# input3: office assistant -> pred:  technician [ 126 ]
# Predicting job role for  accounting assistant ...
# input: accounting assistant -> pred:  unknown [ 148 ]
# Predicting job role for  retail sales consultant ...
# input3: retail sales consultant -> pred:  technician [ 126 ]
# Predicting job role for  front desk- galbraith tennis center ...
# input: front desk- galbraith tennis center -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  assembler power plant ...
# input3: assembler power plant -> pred:  technician [ 126 ]
# Predicting job role for  bakery clerk ...
# input3: bakery clerk -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  30104 ; 029 ; assembler inst elec syst b ...
# input3: 30104 ; 029 ; assembler inst elec syst b -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part time flexible hours ...
# input: warehouse team member seasonal part time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  customer service representative ...
# input3: customer service representative -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part time flexible hours ...
# input: warehouse team member seasonal part time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  warehouse associate ...
# input3: warehouse associate -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  server ...
# input3: server -> pred:  technician [ 126 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  customer experience rep repair ...
# input3: customer experience rep repair -> pred:  technician [ 126 ]
# Predicting job role for  day warehouse associate ...
# input3: day warehouse associate -> pred:  technician [ 126 ]
# Predicting job role for  service consultant ...
# input3: service consultant -> pred:  technician [ 126 ]
# Predicting job role for  assembler electrical w7004 ...
# input3: assembler electrical w7004 -> pred:  technician [ 126 ]
# Predicting job role for  medical records/telephone reception clerk ...
# input3: medical records/telephone reception clerk -> pred:  technician [ 126 ]
# Predicting job role for  concierge/front desk/office ...
# input3: concierge/front desk/office -> pred:  technician [ 126 ]
# Predicting job role for  aerial lineman ...
# input3: aerial lineman -> pred:  technician [ 126 ]
# Predicting job role for  paw print specialist crematory operations ...
# input3: paw print specialist crematory operations -> pred:  specialist [ 125 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse associate ...
# input3: warehouse associate -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  amazon go retail associate full-time & part-time ...
# input: amazon go retail associate full-time & part-time -> pred:  unknown [ 148 ]
# Predicting job role for  ft order selectors needed $ 14/ $ 15 + incentive and $ 2080.00 bonus ! ...
# input3: ft order selectors needed $ 14/ $ 15 + incentive and $ 2080.00 bonus ! -> pred:  technician [ 126 ]
# Predicting job role for  finance assistant ...
# input3: finance assistant -> pred:  technician [ 126 ]
# Predicting job role for  front desk medical receptionist ...
# input3: front desk medical receptionist -> pred:  technician [ 126 ]
# Predicting job role for  batcher ...
# input3: batcher -> pred:  technician [ 126 ]
# Predicting job role for  animal care attendant ...
# input3: animal care attendant -> pred:  technician [ 126 ]
# Predicting job role for  job # 19-51 appraisal technician ...
# input3: job # 19-51 appraisal technician -> pred:  technician [ 126 ]
# Predicting job role for  marina fork lift operator ...
# input3: marina fork lift operator -> pred:  technician [ 126 ]
# Predicting job role for  auditing analyst ...
# input: auditing analyst -> pred:  Analyst [ 138 ]
# Predicting job role for  assembler ...
# input3: assembler -> pred:  technician [ 126 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part time flexible hours ...
# input: warehouse team member seasonal part time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  qa system coordinator ...
# input3: qa system coordinator -> pred:  technician [ 126 ]
# Predicting job role for  dispatch specialist sumner wa ...
# input3: dispatch specialist sumner wa -> pred:  specialist [ 125 ]
# Predicting job role for  quality control assistant ...
# input3: quality control assistant -> pred:  technician [ 126 ]
# Predicting job role for  admin assistant ...
# input3: admin assistant -> pred:  technician [ 126 ]
# Predicting job role for  staff scheduler ...
# input3: staff scheduler -> pred:  technician [ 126 ]
# Predicting job role for  medical records custodian ...
# input3: medical records custodian -> pred:  technician [ 126 ]
# Predicting job role for  fabric worker supervisor i ...
# input3: fabric worker supervisor i -> pred:  technician [ 126 ]
# Predicting job role for  am receiver ...
# input3: am receiver -> pred:  technician [ 126 ]
# Predicting job role for  material handler full-time ...
# input: material handler full-time -> pred:  unknown [ 148 ]
# Predicting job role for  assistant bookkeeper | growing ecommerce company ...
# input3: assistant bookkeeper | growing ecommerce company -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  culinary team member ...
# input3: culinary team member -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  warehouse associate ...
# input3: warehouse associate -> pred:  technician [ 126 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part time flexible hours ...
# input: warehouse team member seasonal part time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  call center treatment coordinator ...
# input: call center treatment coordinator -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  customer construction representative ...
# input3: customer construction representative -> pred:  technician [ 126 ]
# Predicting job role for  general laborer/flagger ...
# input3: general laborer/flagger -> pred:  technician [ 126 ]
# Predicting job role for  newspaper reporter ...
# input3: newspaper reporter -> pred:  technician [ 126 ]
# Predicting job role for  warehouse workers needed $ 14/ $ 15 + incentive + $ 2080.00 bonus ...
# input3: warehouse workers needed $ 14/ $ 15 + incentive + $ 2080.00 bonus -> pred:  technician [ 126 ]
# Predicting job role for  customer service representative ...
# input3: customer service representative -> pred:  technician [ 126 ]
# Predicting job role for  lay up tech ...
# input3: lay up tech -> pred:  technician [ 126 ]
# Predicting job role for  customer service representative ...
# input3: customer service representative -> pred:  technician [ 126 ]
# Predicting job role for  dental receptionist ...
# input3: dental receptionist -> pred:  technician [ 126 ]
# Predicting job role for  office assistant ...
# input3: office assistant -> pred:  technician [ 126 ]
# Predicting job role for  call center representative ...
# input: call center representative -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part time flexible hours ...
# input: warehouse team member seasonal part time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  acquisitions associate ...
# input3: acquisitions associate -> pred:  technician [ 126 ]
# Predicting job role for  qc technician ...
# input3: qc technician -> pred:  technician [ 126 ]
# Predicting job role for  customer business analyst ...
# input: customer business analyst -> pred:  Analyst [ 138 ]
# Predicting job role for  composite/plastic worker ...
# input3: composite/plastic worker -> pred:  technician [ 126 ]
# Predicting job role for  sales associate ...
# input3: sales associate -> pred:  technician [ 126 ]
# Predicting job role for  security officer ...
# input3: security officer -> pred:  technician [ 126 ]
# Predicting job role for  opportunity council wchd healthy futures vista yr2 ...
# input3: opportunity council wchd healthy futures vista yr2 -> pred:  technician [ 126 ]
# Predicting job role for  staff administrative specialist ...
# input3: staff administrative specialist -> pred:  specialist [ 125 ]
# Predicting job role for  warehouse team member seasonal part time flexible hours ...
# input: warehouse team member seasonal part time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  sales coordinator inside sales ...
# input3: sales coordinator inside sales -> pred:  technician [ 126 ]
# Predicting job role for  sales coordinator ...
# input3: sales coordinator -> pred:  technician [ 126 ]
# Predicting job role for  retail cashier ...
# input3: retail cashier -> pred:  technician [ 126 ]
# Predicting job role for  receptionist ...
# input3: receptionist -> pred:  technician [ 126 ]
# Predicting job role for  meatcutting worker ...
# input3: meatcutting worker -> pred:  technician [ 126 ]
# Predicting job role for  custodian ...
# input3: custodian -> pred:  technician [ 126 ]
# Predicting job role for  am vegetable prep veg prep ...
# input3: am vegetable prep veg prep -> pred:  technician [ 126 ]
# Predicting job role for  dshs oos language testing & certification manager ...
# input: dshs oos language testing & certification manager -> pred:  unknown [ 148 ]
# Predicting job role for  recreational aide ...
# input3: recreational aide -> pred:  technician [ 126 ]
# Predicting job role for  bi-weekly live-in- $ 3300 per month ...
# input3: bi-weekly live-in- $ 3300 per month -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part time flexible hours ...
# input: warehouse team member seasonal part time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  customer service dispatcher ...
# input3: customer service dispatcher -> pred:  technician [ 126 ]
# Predicting job role for  contract administrator ...
# input3: contract administrator -> pred:  technician [ 126 ]
# Predicting job role for  ft warehouse workers chehalis wa $ 14/ $ 15 + incentive and $ 2080 bonus ! ...
# input3: ft warehouse workers chehalis wa $ 14/ $ 15 + incentive and $ 2080 bonus ! -> pred:  technician [ 126 ]
# Predicting job role for  `` yard magician '' yard technician ...
# input3: `` yard magician '' yard technician -> pred:  technician [ 126 ]
# Predicting job role for  demand writer ...
# input3: demand writer -> pred:  technician [ 126 ]
# Predicting job role for  procurement technician ...
# input3: procurement technician -> pred:  technician [ 126 ]
# Predicting job role for  corporate relations coordinator ...
# input3: corporate relations coordinator -> pred:  technician [ 126 ]
# Predicting job role for  diamond operations coordinator ...
# input: diamond operations coordinator -> pred:  unknown [ 148 ]
# Predicting job role for  dispatcher ...
# input3: dispatcher -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  ltl freight shipping logistics manager ...
# input3: ltl freight shipping logistics manager -> pred:  technician [ 126 ]
# Predicting job role for  accounts payable/accounts receivable specialist ...
# input3: accounts payable/accounts receivable specialist -> pred:  specialist [ 125 ]
# Predicting job role for  scrap metal laborer entry level ...
# input3: scrap metal laborer entry level -> pred:  technician [ 126 ]
# Predicting job role for  fedex delivery driver renton area $ 18.75/hr- $ 24/hr medical ...
# input: fedex delivery driver renton area $ 18.75/hr- $ 24/hr medical -> pred:  IT [ 54 ]
# Predicting job role for  mortgage services assistant ...
# input: mortgage services assistant -> pred:  unknown [ 148 ]
# Predicting job role for  dishwasher ...
# input3: dishwasher -> pred:  technician [ 126 ]
# Predicting job role for  large boat skipper ...
# input3: large boat skipper -> pred:  technician [ 126 ]
# Predicting job role for  technical recruiter ...
# input3: technical recruiter -> pred:  technical [ 132 ]
# Predicting job role for  customer service representative alderwood ...
# input3: customer service representative alderwood -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part time flexible hours ...
# input: warehouse team member seasonal part time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  paw print specialist crematory operations ...
# input3: paw print specialist crematory operations -> pred:  specialist [ 125 ]
# Predicting job role for  medical billing specialist ...
# input3: medical billing specialist -> pred:  specialist [ 125 ]
# Predicting job role for  vehicle detailer ...
# input3: vehicle detailer -> pred:  technician [ 126 ]
# Predicting job role for  driver ...
# input3: driver -> pred:  technician [ 126 ]
# Predicting job role for  legal practice assistant ...
# input3: legal practice assistant -> pred:  technician [ 126 ]
# Predicting job role for  customer service representative ...
# input3: customer service representative -> pred:  technician [ 126 ]
# Predicting job role for  veterinary assistant ...
# input3: veterinary assistant -> pred:  technician [ 126 ]
# Predicting job role for  collections specialist ...
# input3: collections specialist -> pred:  specialist [ 125 ]
# Predicting job role for  leasing associate ...
# input3: leasing associate -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal kent washington united states ...
# input: warehouse team member part-time seasonal kent washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  medical records technician coder cdis ...
# input3: medical records technician coder cdis -> pred:  technician [ 126 ]
# Predicting job role for  auction inspector kent washington ...
# input3: auction inspector kent washington -> pred:  technician [ 126 ]
# Predicting job role for  housekeeper ...
# input3: housekeeper -> pred:  technician [ 126 ]
# Predicting job role for  room attendant/housekeeping ...
# input3: room attendant/housekeeping -> pred:  technician [ 126 ]
# Predicting job role for  procurement analyst ...
# input: procurement analyst -> pred:  Analyst [ 138 ]
# Predicting job role for  evidence handling analyst ...
# input: evidence handling analyst -> pred:  Analyst [ 138 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal kent washington united states ...
# input: warehouse team member part-time seasonal kent washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  automotive technician-2055-ft ...
# input3: automotive technician-2055-ft -> pred:  technician [ 126 ]
# Predicting job role for  personal injury paralegal/legal assistant ...
# input3: personal injury paralegal/legal assistant -> pred:  technician [ 126 ]
# Predicting job role for  front desk receptionist optometry ...
# input3: front desk receptionist optometry -> pred:  technician [ 126 ]
# Predicting job role for  handyman apprentice ...
# input3: handyman apprentice -> pred:  technician [ 126 ]
# Predicting job role for  counter sales representative ...
# input3: counter sales representative -> pred:  technician [ 126 ]
# Predicting job role for  overnight bread baker ...
# input3: overnight bread baker -> pred:  technician [ 126 ]
# Predicting job role for  loan officer ...
# input3: loan officer -> pred:  technician [ 126 ]
# Predicting job role for  grain elevator yard worker ...
# input3: grain elevator yard worker -> pred:  technician [ 126 ]
# Predicting job role for  leasing service advisor ...
# input3: leasing service advisor -> pred:  technician [ 126 ]
# Predicting job role for  service experience the outlet collection rack ...
# input3: service experience the outlet collection rack -> pred:  technician [ 126 ]
# Predicting job role for  on call corrections tech work release $ 17.50/hr ! ...
# input3: on call corrections tech work release $ 17.50/hr ! -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal kent washington united states ...
# input: warehouse team member part-time seasonal kent washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  mortgage loan processor ...
# input3: mortgage loan processor -> pred:  technician [ 126 ]
# Predicting job role for  legal assistant/secretary ...
# input3: legal assistant/secretary -> pred:  technician [ 126 ]
# Predicting job role for  human resources specialist employee/labor relations ...
# input3: human resources specialist employee/labor relations -> pred:  specialist [ 125 ]
# Predicting job role for  general handyman ...
# input3: general handyman -> pred:  technician [ 126 ]
# Predicting job role for  construction detailer ...
# input3: construction detailer -> pred:  technician [ 126 ]
# Predicting job role for  graveyard security/bellperson ...
# input3: graveyard security/bellperson -> pred:  technician [ 126 ]
# Predicting job role for  tailor ...
# input3: tailor -> pred:  technician [ 126 ]
# Predicting job role for  behavioral health outreach – americorps vista ...
# input3: behavioral health outreach – americorps vista -> pred:  technician [ 126 ]
# Predicting job role for  signals intelligence analyst 35n ...
# input: signals intelligence analyst 35n -> pred:  Analyst [ 138 ]
# Predicting job role for  warehouse lead/supervisor ...
# input3: warehouse lead/supervisor -> pred:  technician [ 126 ]
# Predicting job role for  pm front house harvest harvest ...
# input3: pm front house harvest harvest -> pred:  technician [ 126 ]
# Predicting job role for  automotive advisor ...
# input3: automotive advisor -> pred:  technician [ 126 ]
# Predicting job role for  assistant manager ...
# input3: assistant manager -> pred:  technician [ 126 ]
# Predicting job role for  supervisory procurement analyst ...
# input: supervisory procurement analyst -> pred:  Analyst [ 138 ]
# Predicting job role for  outside sales representative ...
# input3: outside sales representative -> pred:  technician [ 126 ]
# Predicting job role for  caregiver ...
# input3: caregiver -> pred:  technician [ 126 ]
# Predicting job role for  bim professional ...
# input3: bim professional -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  front desk insurance coordinator ...
# input3: front desk insurance coordinator -> pred:  technician [ 126 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal kent washington united states ...
# input: warehouse team member part-time seasonal kent washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  am houseman ...
# input3: am houseman -> pred:  technician [ 126 ]
# Predicting job role for  retail assistant manager ...
# input3: retail assistant manager -> pred:  technician [ 126 ]
# Predicting job role for  customer service call center representative ...
# input: customer service call center representative -> pred:  unknown [ 148 ]
# Predicting job role for  painter ...
# input3: painter -> pred:  technician [ 126 ]
# Predicting job role for  pastry baker ...
# input3: pastry baker -> pred:  technician [ 126 ]
# Predicting job role for  paint prep technician ...
# input3: paint prep technician -> pred:  technician [ 126 ]
# Predicting job role for  lakewood caregiving heavy hoyer lift experience required ...
# input3: lakewood caregiving heavy hoyer lift experience required -> pred:  technician [ 126 ]
# Predicting job role for  project manager ...
# input: project manager -> pred:  unknown [ 148 ]
# Predicting job role for  automotive manager prev exp req 'd ...
# input3: automotive manager prev exp req 'd -> pred:  technician [ 126 ]
# Predicting job role for  administrative coordinator-billing dept ...
# input3: administrative coordinator-billing dept -> pred:  technician [ 126 ]
# Predicting job role for  field service technician- bellevue wa ...
# input: field service technician- bellevue wa -> pred:  IT [ 128 ]
# Predicting job role for  maintenance assistant ...
# input3: maintenance assistant -> pred:  technician [ 126 ]
# Predicting job role for  awake overnight direct support professional ...
# input: awake overnight direct support professional -> pred:  unknown [ 148 ]
# Predicting job role for  maintenance assistant ...
# input3: maintenance assistant -> pred:  technician [ 126 ]
# Predicting job role for  customer service representative/inside sales ...
# input3: customer service representative/inside sales -> pred:  technician [ 126 ]
# Predicting job role for  activities assistant memory care ...
# input3: activities assistant memory care -> pred:  technician [ 126 ]
# Predicting job role for  evening janitorial opening ...
# input3: evening janitorial opening -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal kent washington united states ...
# input: warehouse team member part-time seasonal kent washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  cyp program assistant ...
# input: cyp program assistant -> pred:  unknown [ 148 ]
# Predicting job role for  automotive advisor ...
# input3: automotive advisor -> pred:  technician [ 126 ]
# Predicting job role for  construction analyst ...
# input: construction analyst -> pred:  Analyst [ 138 ]
# Predicting job role for  field service technician ...
# input3: field service technician -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal kent washington united states ...
# input: warehouse team member part-time seasonal kent washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  culinary team member ...
# input3: culinary team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse receiver/production supplier ...
# input3: warehouse receiver/production supplier -> pred:  technician [ 126 ]
# Predicting job role for  account executive ...
# input: account executive -> pred:  unknown [ 148 ]
# Predicting job role for  crew member/cashier ...
# input3: crew member/cashier -> pred:  technician [ 126 ]
# Predicting job role for  retail store manager ...
# input3: retail store manager -> pred:  technician [ 126 ]
# Predicting job role for  hotel custodian houseman ...
# input3: hotel custodian houseman -> pred:  technician [ 126 ]
# Predicting job role for  am dish machine operator dmo ...
# input3: am dish machine operator dmo -> pred:  machine operator [ 73 ]
# Predicting job role for  weekend caregiving ...
# input3: weekend caregiving -> pred:  technician [ 126 ]
# Predicting job role for  dishwasher/food prep ...
# input3: dishwasher/food prep -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal kent washington united states ...
# input: warehouse team member part-time seasonal kent washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  culinary team member ...
# input3: culinary team member -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  hotel maintenance ...
# input3: hotel maintenance -> pred:  technician [ 126 ]
# Predicting job role for  lead medical administrative assistant ...
# input3: lead medical administrative assistant -> pred:  technician [ 126 ]
# Predicting job role for  fire safety technician ...
# input3: fire safety technician -> pred:  technician [ 126 ]
# Predicting job role for  swing position driver ...
# input3: swing position driver -> pred:  technician [ 126 ]
# Predicting job role for  daytime caregiving ...
# input3: daytime caregiving -> pred:  technician [ 126 ]
# Predicting job role for  service fish section manager ...
# input3: service fish section manager -> pred:  technician [ 126 ]
# Predicting job role for  dietary aide kitchen phsw medical center ...
# input: dietary aide kitchen phsw medical center -> pred:  unknown [ 148 ]
# Predicting job role for  experienced 02 electrical apprentices wanted ...
# input3: experienced 02 electrical apprentices wanted -> pred:  technician [ 126 ]
# Predicting job role for  school age day camp site director ...
# input3: school age day camp site director -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# ...
# Predicting job role for  printing bindery operator inserter operators ...
# input3: printing bindery operator inserter operators -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member part-time seasonal kent washington united states ...
# input: warehouse team member part-time seasonal kent washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  cargo handlers dock ...
# input3: cargo handlers dock -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  cargo handlers dock ...
# input3: cargo handlers dock -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  30104 ; 029 ; assembler inst elec syst b ...
# input3: 30104 ; 029 ; assembler inst elec syst b -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal kent washington united states ...
# input: warehouse team member part-time seasonal kent washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  warehouse associate ...
# input3: warehouse associate -> pred:  technician [ 126 ]
# Predicting job role for  cargo handlers dock ...
# input3: cargo handlers dock -> pred:  technician [ 126 ]
# Predicting job role for  material handler ...
# input3: material handler -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  30104 ; 029 ; assembler inst elec syst b ...
# input3: 30104 ; 029 ; assembler inst elec syst b -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member full-time ...
# input: warehouse team member full-time -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  30104 ; 029 ; assembler inst elec syst b ...
# input3: 30104 ; 029 ; assembler inst elec syst b -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  warehouse associate ...
# input3: warehouse associate -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  culinary team member ...
# input3: culinary team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  cargo handlers dock ...
# input3: cargo handlers dock -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse associate ...
# input3: warehouse associate -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  call center treatment coordinator ...
# input: call center treatment coordinator -> pred:  unknown [ 148 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part time flexible hours ...
# input: warehouse team member seasonal part time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  30104 ; 029 ; assembler inst elec syst b ...
# input3: 30104 ; 029 ; assembler inst elec syst b -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  cargo handlers dock ...
# input3: cargo handlers dock -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  call center treatment coordinator ...
# input: call center treatment coordinator -> pred:  unknown [ 148 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  call center treatment coordinator ...
# input: call center treatment coordinator -> pred:  unknown [ 148 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  warehouse associate ...
# input3: warehouse associate -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  encapsulation machine operator ...
# input3: encapsulation machine operator -> pred:  machine operator [ 73 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  cargo handlers dock ...
# input3: cargo handlers dock -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  30104 ; 029 ; assembler inst elec syst b ...
# input3: 30104 ; 029 ; assembler inst elec syst b -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  materials purchaser centralia ...
# input3: materials purchaser centralia -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  30104 ; 029 ; assembler inst elec syst b ...
# input3: 30104 ; 029 ; assembler inst elec syst b -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member dupont washington united states ...
# input3: warehouse team member dupont washington united states -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  warehouse associate ...
# input3: warehouse associate -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  call center treatment coordinator ...
# input: call center treatment coordinator -> pred:  unknown [ 148 ]
# Predicting job role for  cargo handlers dock ...
# input3: cargo handlers dock -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  30104 ; 029 ; assembler inst elec syst b ...
# input3: 30104 ; 029 ; assembler inst elec syst b -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member seasonal part time flexible hours ...
# input: warehouse team member seasonal part time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  30104 ; 029 ; assembler inst elec syst b ...
# input3: 30104 ; 029 ; assembler inst elec syst b -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member part-time seasonal renton washington united states ...
# input: warehouse team member part-time seasonal renton washington united states -> pred:  unknown [ 148 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  project managers all levels ...
# input: project managers all levels -> pred:  unknown [ 148 ]
# Predicting job role for  warehouse team member seasonal part-time flexible hours ...
# input: warehouse team member seasonal part-time flexible hours -> pred:  unknown [ 148 ]
# Predicting job role for  cargo handlers dock ...
# input3: cargo handlers dock -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  assembler power plant ...
# input3: assembler power plant -> pred:  technician [ 126 ]
# Predicting job role for  warehouse team member ...
# input3: warehouse team member -> pred:  technician [ 126 ]
# Predicting job role for  assembler installer ...
# input3: assembler installer -> pred:  technician [ 126 ]
# Predicting job role for  assistant head grower ...
# input3: assistant head grower -> pred:  technician [ 126 ]
# Predicting job role for  30104 ; 029 ; assembler inst elec syst b ...
# input3: 30104 ; 029 ; assembler inst elec syst b -> pred:  technician [ 126 ]

# %% [markdown]
# # Run job scrape function to pull skills and other information from scraped data set with job roles

# %%
urls = list(combined_dfs["IndeedJobListingURL"])
print(urls)

applicationURL, jobDescription, genBullets, goodToHaveBullets, requiredBullets, hasBulletPoints, \
genSkills, goodToHaveSkills, requiredSkills, lastUpdated = jobScrape(urls)

combined_dfs['FullDescription'] = jobDescription
combined_dfs['GenBulletPoints'] = genBullets
combined_dfs['GoodToHaveBulletPoints'] = goodToHaveBullets
combined_dfs['RequiredBulletPoints'] = requiredBullets
combined_dfs['HasBulletPoints'] = hasBulletPoints
combined_dfs['genSkills'] = genSkills
combined_dfs['GoodToHaveAssociatedSkills'] = goodToHaveSkills
combined_dfs['RequiredAssociatedSkills'] = requiredSkills
combined_dfs['ApplicationURL'] = applicationURL
combined_dfs['LastUpdated'] = lastUpdated

combined_dfs.to_csv("data.csv", index=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a9e299707b0> in <module>()
# ----> 1 urls = list(combined_dfs["IndeedJobListingURL"])
#       2 print(urls)
#       3
#       4 applicationURL, jobDescription, genBullets, goodToHaveBullets, requiredBullets, hasBulletPoints, genSkills, goodToHaveSkills, requiredSkills, lastUpdated = jobScrape(urls)
#       5
#
# NameError: name 'combined_dfs' is not defined
